# %%
import random
import numpy as np
import math

# %%
N=100
Integral=0 

naccept=0  

randomNumbers=[] # output list of random numbers  

for i in range(N):
    pointX=(random.uniform(0,np.pi/2)) #X range
    pointY=(random.uniform(0,1))    #Y range of sine
      
    if pointY<math.sin(pointX):  
        randomNumbers.append(pointX)  
        naccept=naccept+1

print(randomNumbers)
# Out:
# [1.524588617457576, 1.1046652617831254, 0.6694877641598198, 0.8588845453693832, 0.5813932430347484, 1.3843146858187294, 0.21972229519992548, 0.3775016738398507, 1.4046094685174744, 1.4935880664128802, 1.4487683257189798, 1.2984902518672046, 0.5870359121074515, 1.3101411235298819, 0.6529842408861259, 1.5291294778063051, 1.377116477088216, 0.8970736442255134, 1.4313986815481694, 0.9469398879558981, 1.122134389204455, 0.8725973629560961, 0.46567291466781063, 0.8514750696282466, 0.7197764914645447, 0.24338758869748248, 1.5378950775675557, 1.1003138794056004, 0.5393959567423948, 1.0067838501118322, 1.111146193300405, 1.2481587075343639, 0.8860772127251866, 1.223774466554198, 1.506409536703868, 1.0802494276687595, 0.817904884567715, 0.9050405282730273, 1.4312729163500453, 1.5384176025130922, 1.5081234852299266, 1.3273611035691955, 0.5278733391536092, 1.1286224311734148, 1.1808533959175156, 1.3826641425267805, 1.244837314629523, 1.4720518465057881, 0.9210629848452501, 1.3167632210613849, 0.
# ...
