# %%
import random
import numpy as np
import math

# %%
N=100000
Integral=0
for i in range(N):
    point=(random.uniform(0,pi/2))
    Integral += math.cos(point)
    
answer=pi/2*Integral/N
print(answer)
# Out:
# 1.0019023336228323
